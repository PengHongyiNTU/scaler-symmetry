# %%
import pandas as pd
import seaborn as sns
df = pd.read_csv('sanity_check.csv')
sns.lineplot(x='alpha', y='Test Acc', hue='with permutation', data=df, 
             style='with permutation')
# Out:
# <Axes: xlabel='alpha', ylabel='Test Acc'>
